# %%
import pandas as pd
import sns
import train
import holidays

df = pd.read_csv('cleaneddata.csv')
# df
# Out:
# /var/folders/_4/yzd4h3k95051tj7kpg425rk80000gn/T/ipykernel_97790/806190366.py:6: DtypeWarning: Columns (11,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('cleaneddata.csv')

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.metrics import classification_report, mean_absolute_error, mean_squared_error
from matplotlib import pyplot as plt

# %%
de_holidays = holidays.Germany(prov='NW')

# %%
pd.set_option('display.max_columns', None)

print(df.head())
# Out:
#            DateOfOrder   OrderId                     TransactionId  \
# 0  2019-12-02 20:39:46  11161800  5fff5813ae674809a06e3b1fe5528fcf
# 1  2019-12-02 20:39:46  11161801  7c4f0e97356e46669abefe8dc5fb0ff0
# 2  2019-12-03 22:29:24  11166739  ee1d1a4a7458414a8bb420111ba0fa8c
# 3  2019-12-04 13:27:22  11169532  86497dc4e7434b838a335c439325fb65
# 4  2019-12-04 13:27:22  11169533  6054345ad0b14bd297dbdc6372ff1488
#
#   DateOfService  OrderQty          MenuName  MenuPrice  MenuSubsidy  \
# 0    2020-01-02         1  Mittagessen (BS)       3.05          0.0
# 1    2020-01-03         1  Mittagessen (BS)       3.05          0.0
# 2    2020-01-02         1  Mittagessen (BS)       3.05          0.0
# 3    2020-01-02         1  Mittagessen (BS)       3.05          0.0
# 4    2020-01-03         1  Mittagessen (BS)       3.05          0.0
#
#        BookingNr       GroupName  CanceledQty DateOfCancel Site SchoolID  \
# 0  474-136052114  Bad Sassendorf            0          NaN   LP   SCH003
# 1  474-136052114  Bad Sassendorf            0          NaN   LP   SCH003
# 2  474-136060130  Bad Sassendorf            0          NaN   LP   SCH003
# 3  474-136047096  Bad Sassendorf            0          NaN   LP   SCH003
# 4  474-136047096  Bad Sassendorf            0          NaN   LP   SCH003
#
#    net_qty  days_to_cancel          MenuNorm     MenuBase MenuCode  \
# 0        1              -1  MITTAGESSEN (BS)  MITTAGESSEN       BS
# 1        1              -1  MITTAGESSEN (BS)  MITTAGESSEN       BS
# 2        1              -1  MITTAGESSEN (BS)  MITTAGESSEN       BS
# 3        1              -1  MITTAGESSEN (BS)  MITTAGESSEN       BS
# 4        1              -1  MITTAGESSEN (BS)  MITTAGESSEN       BS
#
#    day_of_year  weekday  is_weekend   sin_doy   cos_doy cancel_timing  \
# 0          336        1           0 -0.963471 -0.267814           NaN
# 1          336        1           0 -0.963471 -0.267814           NaN
# 2          337        2           0 -0.963471 -0.267814           NaN
# 3          338        3           0 -0.963471 -0.267814           NaN
# 4          338        3           0 -0.963471 -0.267814           NaN
#
#    subsidy_pct  month  quarter  day_of_month  is_month_end  is_month_start  \
# 0          0.0     12        4             2             0               0
# 1          0.0     12        4             2             0               0
# 2          0.0     12        4             3             0               0
# 3          0.0     12        4             4             0               0
# 4          0.0     12        4             4             0               0
#
#    order_hour  morning  afternoon  evening  hist_cancel_rate  is_holiday
# 0          20        0          0        1            1.0499           0
# 1          20        0          0        1            1.0499           0
# 2          22        0          0        1            1.0499           0
# 3          13        0          1        0            1.0499           0
# 4          13        0          1        0            1.0499           0

# %%
df
# Out:
#                  DateOfOrder   OrderId  \
# 0        2019-12-02 20:39:46  11161800
# 1        2019-12-02 20:39:46  11161801
# 2        2019-12-03 22:29:24  11166739
# 3        2019-12-04 13:27:22  11169532
# 4        2019-12-04 13:27:22  11169533
# ...                      ...       ...
# 5671161  2024-08-27 11:54:08  28525140
# 5671162  2024-08-27 11:54:09  28525148
# 5671163  2024-08-27 11:54:11  28525166
# 5671164  2024-08-27 11:54:12  28525175
# 5671165  2024-08-27 11:54:13  28525185
#
#                                   TransactionId DateOfService  OrderQty  \
# 0              5fff5813ae674809a06e3b1fe5528fcf    2020-01-02         1
# 1              7c4f0e97356e46669abefe8dc5fb0ff0    2020-01-03         1
# 2              ee1d1a4a7458414a8bb420111ba0fa8c    2020-01-02         1
# 3              86497dc4e7434b838a335c439325fb65    2020-01-02         1
# 4              6054345ad0b14bd297dbdc6372ff1488    2020-01-03         1
# ...                                         ...           ...       ...
# 5671161  3afb68785a33434d8a5d33464e400d94_order    2023-12-14         1
# 5671162  4ae5064b9fc24653becf25d6dca02cac_order    2023-12-15         1
# 5671163  5a3c0717d64542ba95c10751b97be085_order    2023-12-18         1
# 5671164  5132cd3f4237409a9e700a9ad8c47da2_order    2023-12-19         1
# 5671165  a5cdd9927c724f49906b5652e9be57ef_order    2023-12-20         1
#
#                  MenuName  MenuPrice  MenuSubsidy      BookingNr  \
# 0        Mittagessen (BS)       3.05         0.00  474-136052114
# 1        Mittagessen (BS)       3.05         0.00  474-136052114
# 2        Mittagessen (BS)       3.05         0.00  474-136060130
# 3        Mittagessen (BS)       3.05         0.00  474-136047096
# 4        Mittagessen (BS)       3.05         0.00  474-136047096
# ...                   ...        ...          ...            ...
# 5671161  Mittagessen (BK)       0.00         4.15  900-170863713
# 5671162  Mittagessen (BK)       0.00         4.15  900-170863713
# 5671163  Mittagessen (BK)       0.00         4.15  900-170863713
# 5671164  Mittagessen (BK)       0.00         4.15  900-170863713
# 5671165  Mittagessen (BK)       0.00         4.15  900-170863713
#
#               GroupName  CanceledQty DateOfCancel Site SchoolID  net_qty  \
# 0        Bad Sassendorf            0          NaN   LP   SCH003        1
# 1        Bad Sassendorf            0          NaN   LP   SCH003        1
# 2        Bad Sassendorf            0          NaN   LP   SCH003        1
# 3        Bad Sassendorf            0          NaN   LP   SCH003        1
# 4        Bad Sassendorf            0          NaN   LP   SCH003        1
# ...                 ...          ...          ...  ...      ...      ...
# 5671161   Hamm ermäßigt            0          NaN   BK   SCH139        1
# 5671162   Hamm ermäßigt            0          NaN   BK   SCH139        1
# 5671163   Hamm ermäßigt            0          NaN   BK   SCH139        1
# 5671164   Hamm ermäßigt            0          NaN   BK   SCH139        1
# 5671165   Hamm ermäßigt            0          NaN   BK   SCH139        1
#
#          days_to_cancel          MenuNorm     MenuBase MenuCode  day_of_year  \
# 0                    -1  MITTAGESSEN (BS)  MITTAGESSEN       BS          336
# 1                    -1  MITTAGESSEN (BS)  MITTAGESSEN       BS          336
# 2                    -1  MITTAGESSEN (BS)  MITTAGESSEN       BS          337
# 3                    -1  MITTAGESSEN (BS)  MITTAGESSEN       BS          338
# 4                    -1  MITTAGESSEN (BS)  MITTAGESSEN       BS          338
# ...                 ...               ...          ...      ...          ...
# 5671161              -1  MITTAGESSEN (BK)  MITTAGESSEN       BK          240
# 5671162              -1  MITTAGESSEN (BK)  MITTAGESSEN       BK          240
# 5671163              -1  MITTAGESSEN (BK)  MITTAGESSEN       BK          240
# 5671164              -1  MITTAGESSEN (BK)  MITTAGESSEN       BK          240
# 5671165              -1  MITTAGESSEN (BK)  MITTAGESSEN       BK          240
#
#          weekday  is_weekend   sin_doy   cos_doy cancel_timing  subsidy_pct  \
# 0              1           0 -0.963471 -0.267814           NaN          0.0
# 1              1           0 -0.963471 -0.267814           NaN          0.0
# 2              2           0 -0.963471 -0.267814           NaN          0.0
# 3              3           0 -0.963471 -0.267814           NaN          0.0
# 4              3           0 -0.963471 -0.267814           NaN          0.0
# ...          ...         ...       ...       ...           ...          ...
# 5671161        2           0 -0.963471 -0.267814           NaN          inf
# 5671162        2           0 -0.963471 -0.267814           NaN          inf
# 5671163        2           0 -0.963471 -0.267814           NaN          inf
# 5671164        2           0 -0.963471 -0.267814           NaN          inf
# 5671165        2           0 -0.963471 -0.267814           NaN          inf
#
#          month  quarter  day_of_month  is_month_end  is_month_start  \
# 0           12        4             2             0               0
# 1           12        4             2             0               0
# 2           12        4             3             0               0
# 3           12        4             4             0               0
# 4           12        4             4             0               0
# ...        ...      ...           ...           ...             ...
# 5671161      8        3            27             0               0
# 5671162      8        3            27             0               0
# 5671163      8        3            27             0               0
# 5671164      8        3            27             0               0
# 5671165      8        3            27             0               0
#
#          order_hour  morning  afternoon  evening  hist_cancel_rate  is_holiday
# 0                20        0          0        1          1.049900           0
# 1                20        0          0        1          1.049900           0
# 2                22        0          0        1          1.049900           0
# 3                13        0          1        0          1.049900           0
# 4                13        0          1        0          1.049900           0
# ...             ...      ...        ...      ...               ...         ...
# 5671161          11        1          0        0          0.995023           0
# 5671162          11        1          0        0          0.995023           0
# 5671163          11        1          0        0          0.995023           0
# 5671164          11        1          0        0          0.995023           0
# 5671165          11        1          0        0          0.995023           0
#
# [5671166 rows x 37 columns]

# %%
# checking if there is still cases remaing wich have Dateofservice before dateoforder

df['DateOfOrder'] = pd.to_datetime(df['DateOfOrder'])
df['DateOfService'] = pd.to_datetime(df['DateOfService'])

filtered_df = df[df['DateOfService'] < df['DateOfOrder'].dt.date]

# %%
# checking for missing sites
print(df['Site'].unique())
# Out:
# ['LP' 'BK' nan 'MS']

# %%
from sklearn.metrics import confusion_matrix
import numpy as np
import seaborn as sns

# --- 1. CANCELLATION PREDICTION ANALYSIS ---
print("\n--- Step 1: Cancellation Prediction Analysis ---")
print("Goal: Understand the drivers of cancellations to improve our net demand forecast.")
df['is_canceled'] = (df['CanceledQty'] > 0).astype(int)

# Feature selection for cancellation model
cancel_features = [
    'MenuPrice', 'MenuSubsidy', 'subsidy_pct', 'day_of_year', 'weekday',
    'is_weekend', 'sin_doy', 'cos_doy', 'month', 'quarter', 'is_month_end',
    'is_month_start', 'order_hour', 'morning', 'afternoon', 'evening',
    'hist_cancel_rate', 'is_holiday'
]
target_cancel = 'is_canceled'

X_cancel = df[cancel_features].copy()
y_cancel = df[target_cancel]


# Handle potential missing values
X_cancel.replace([np.inf, -np.inf], np.nan, inplace=True)
X_cancel = X_cancel.ffill().bfill()
for col in X_cancel.columns:
    if X_cancel[col].isnull().any():
        if pd.api.types.is_numeric_dtype(X_cancel[col]):
            X_cancel[col] = X_cancel[col].fillna(0)
        else:
            X_cancel[col] = X_cancel[col].fillna(X_cancel[col].mode()[0])

# Time-based split for training and testing
split_index = int(len(df) * 0.8)
X_train_c, X_test_c = X_cancel[:split_index], X_cancel[split_index:]
y_train_c, y_test_c = y_cancel[:split_index], y_cancel[split_index:]

# Train RandomForestClassifier
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42, class_weight='balanced', n_jobs=-1)
print("Training cancellation classifier...")
rf_classifier.fit(X_train_c, y_train_c)

# --- VISUALIZATION 1.1: CANCELLATION FEATURE IMPORTANCE ---
print("\nInsight: Visualizing what drives cancellations...")
feature_importances = pd.DataFrame({
    'feature': cancel_features,
    'importance': rf_classifier.feature_importances_
}).sort_values('importance', ascending=False)

plt.figure(figsize=(12, 8))
sns.barplot(x='importance', y='feature', data=feature_importances.head(10), palette='viridis')
plt.title('Top 10 Feature Importances for Cancellation Prediction', fontsize=16)
plt.xlabel('Importance Score', fontsize=12)
plt.ylabel('Feature', fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# --- VISUALIZATION 1.2: CONFUSION MATRIX ---
print("\nInsight: How well does our model distinguish between canceled and non-canceled orders?")
y_pred_c = rf_classifier.predict(X_test_c)
cm = confusion_matrix(y_test_c, y_pred_c)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Not Canceled', 'Canceled'],
            yticklabels=['Not Canceled', 'Canceled'])
plt.title('Cancellation Model Confusion Matrix', fontsize=16)
plt.ylabel('Actual', fontsize=12)
plt.xlabel('Predicted', fontsize=12)
plt.show()

print("\nClassification Report:")
print(classification_report(y_test_c, y_pred_c))
print("Conclusion: The feature importance plot clearly shows that historical cancellation rates and subsidy percentages are key predictors. The confusion matrix gives us a clear picture of the model's accuracy, precision, and recall.")
print("\n--- End of Step 1 ---")
print("-" * 50)
# Out:
# --- Step 1: Cancellation Prediction Analysis ---
# Goal: Understand the drivers of cancellations to improve our net demand forecast.
# Training cancellation classifier...
#
# Insight: Visualizing what drives cancellations...
# /var/folders/_4/yzd4h3k95051tj7kpg425rk80000gn/T/ipykernel_97790/3871864580.py:50: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='importance', y='feature', data=feature_importances.head(10), palette='viridis')
# Insight: How well does our model distinguish between canceled and non-canceled orders?
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99   1113107
#            1       0.02      0.01      0.01     21127
#
#     accuracy                           0.98   1134234
#    macro avg       0.50      0.50      0.50   1134234
# weighted avg       0.96      0.98      0.97   1134234
#
# Conclusion: The feature importance plot clearly shows that historical cancellation rates and subsidy percentages are key predictors. The confusion matrix gives us a clear picture of the model's accuracy, precision, and recall.
#
# --- End of Step 1 ---
# --------------------------------------------------

# %%
# --- 2. DATA PREPARATION FOR FORECASTING ---
print("\n--- Step 2: Data Preparation for Forecasting ---")
print("Goal: Aggregate data and create target variables for future meal counts.")

# Aggregate data to Site-Day level
# We sum the 'net_qty' for each Site on each 'DateOfService'
daily_demand = df.groupby(['DateOfService', 'Site'], observed=False)['net_qty'].sum().reset_index()


# Pivot to have sites as columns, making it easier to process per site
pivot_demand = daily_demand.pivot(index='DateOfService', columns='Site', values='net_qty').fillna(0)

# Create a full date range to ensure no gaps
full_date_range = pd.date_range(start=pivot_demand.index.min(), end=pivot_demand.index.max(), freq='D')
pivot_demand = pivot_demand.reindex(full_date_range, fill_value=0)

# --- VISUALIZATION 2.1: DAILY DEMAND FOR SAMPLE SITES ---
print("\nInsight: Let's visualize the daily demand patterns for a few locations.")
sample_sites = pivot_demand.columns[:min(3, len(pivot_demand.columns))]
pivot_demand[sample_sites].plot(figsize=(15, 7), subplots=False, title='Daily Net Meal Demand for Sample Sites')
plt.ylabel('Net Meal Quantity')
plt.xlabel('Date')
plt.grid(True)
plt.legend(title='Site')
plt.show()

pivot_demand
# Feature Engineering for the forecasting model
# We create time-based features on our complete daily index
time_features = pd.DataFrame(index=pivot_demand.index)
time_features['day_of_year'] = time_features.index.dayofyear
time_features['weekday'] = time_features.index.weekday
time_features['is_weekend'] = time_features.index.weekday >= 5
time_features['month'] = time_features.index.month
time_features['quarter'] = time_features.index.quarter
time_features['day_of_month'] = time_features.index.day
time_features['sin_doy'] = np.sin(2 * np.pi * time_features['day_of_year'] / 365.25)
time_features['cos_doy'] = np.cos(2 * np.pi * time_features['day_of_year'] / 365.25)
# Add holiday info if available for the date range
# For this example, we'll simulate it
# time_features['is_holiday'] = np.random.choice([0, 1], size=len(time_features), p=[0.97, 0.03])
# todois_canceled
time_features['is_holiday'] = time_features.index.to_series().apply(lambda x: int(x in de_holidays))


# Create lagged features and rolling means (important for time series)
for lag in [1, 2, 3, 7, 14]:
    time_features[f'lag_{lag}'] = pivot_demand.shift(lag).mean(axis=1) # Mean demand across all sites 'lag' days ago

time_features['rolling_mean_7'] = time_features['lag_1'].rolling(window=7).mean()
time_features['rolling_mean_14'] = time_features['lag_1'].rolling(window=14).mean()
time_features = time_features.fillna(0)


# Create Target Variables for each horizon
# To predict the future, the target 'y' must be shifted from the future to the current row.
print("\nCreating target variables for different forecast horizons...")

# Horizon 1: <= 1 day (predicting tomorrow's total for each site)
targets_1_day = pivot_demand.shift(-1)

# Horizon 2: 2-5 days (predicting the average demand for days t+2 to t+5 for each site)
targets_2_5_days = pivot_demand.rolling(window=4, min_periods=1).mean().shift(-5)

# Horizon 3: > 5 days (predicting the average demand for days t+6 to t+10 for each site)
targets_6_10_days = pivot_demand.rolling(window=5, min_periods=1).mean().shift(-10)
# ***  Define the target_dfs dictionary ***
target_dfs = {
    'target_1_day': targets_1_day,
    'target_2_5_days': targets_2_5_days,
    'target_6_10_days': targets_6_10_days,
}

print("Target variables created.")
print("\n--- End of Step 2 ---")
# Out:
# --- Step 2: Data Preparation for Forecasting ---
# Goal: Aggregate data and create target variables for future meal counts.
#
# Insight: Let's visualize the daily demand patterns for a few locations.
# Creating target variables for different forecast horizons...
# Target variables created.
#
# --- End of Step 2 ---

# %%
pivot_demand
# Out:
# Site            BK      LP      MS
# 2020-01-02    32.0   169.0     0.0
# 2020-01-03    32.0   184.0     0.0
# 2020-01-04     0.0     1.0     0.0
# 2020-01-05     0.0     0.0     0.0
# 2020-01-06    50.0   696.0     0.0
# ...            ...     ...     ...
# 2023-12-18  6992.0  3669.0  2929.0
# 2023-12-19  3863.0   961.0  2993.0
# 2023-12-20  3544.0  1296.0  2689.0
# 2023-12-21    83.0   280.0  1640.0
# 2023-12-22    16.0     0.0   551.0
#
# [1451 rows x 3 columns]

# %%
time_features
# Out:
#             day_of_year  weekday  is_weekend  month  quarter  day_of_month  \
# 2020-01-02            2        3       False      1        1             2
# 2020-01-03            3        4       False      1        1             3
# 2020-01-04            4        5        True      1        1             4
# 2020-01-05            5        6        True      1        1             5
# 2020-01-06            6        0       False      1        1             6
# ...                 ...      ...         ...    ...      ...           ...
# 2023-12-18          352        0       False     12        4            18
# 2023-12-19          353        1       False     12        4            19
# 2023-12-20          354        2       False     12        4            20
# 2023-12-21          355        3       False     12        4            21
# 2023-12-22          356        4       False     12        4            22
#
#              sin_doy   cos_doy  is_holiday        lag_1        lag_2  \
# 2020-01-02  0.034398  0.999408           0     0.000000     0.000000
# 2020-01-03  0.051584  0.998669           0    67.000000     0.000000
# 2020-01-04  0.068755  0.997634           0    72.000000    67.000000
# 2020-01-05  0.085906  0.996303           0     0.333333    72.000000
# 2020-01-06  0.103031  0.994678           0     0.000000     0.333333
# ...              ...       ...         ...          ...          ...
# 2023-12-18 -0.225964  0.974136           0     0.000000     0.333333
# 2023-12-19 -0.209174  0.977879           0  4530.000000     0.000000
# 2023-12-20 -0.192322  0.981332           0  2605.666667  4530.000000
# 2023-12-21 -0.175413  0.984495           0  2509.666667  2605.666667
# 2023-12-22 -0.158452  0.987367           0   667.666667  2509.666667
#
#                   lag_3        lag_7       lag_14  rolling_mean_7  \
# 2020-01-02     0.000000     0.000000     0.000000        0.000000
# 2020-01-03     0.000000     0.000000     0.000000        0.000000
# 2020-01-04     0.000000     0.000000     0.000000        0.000000
# 2020-01-05    67.000000     0.000000     0.000000        0.000000
# 2020-01-06    72.000000     0.000000     0.000000        0.000000
# ...                 ...          ...          ...             ...
# 2023-12-18  1905.000000  4722.333333  4511.333333     2638.714286
# 2023-12-19     0.333333  2716.666667  2811.333333     2611.238095
# 2023-12-20     0.000000  4558.333333  4540.000000     2595.380952
# 2023-12-21  4530.000000  4568.333333  4775.333333     2302.714286
# 2023-12-22  2605.666667  1905.000000  1934.666667     1745.476190
#
#             rolling_mean_14
# 2020-01-02         0.000000
# 2020-01-03         0.000000
# 2020-01-04         0.000000
# 2020-01-05         0.000000
# 2020-01-06         0.000000
# ...                     ...
# 2023-12-18      2645.976190
# 2023-12-19      2647.309524
# 2023-12-20      2632.619048
# 2023-12-21      2487.595238
# 2023-12-22      2194.190476
#
# [1451 rows x 16 columns]

# %%
target_dfs
# Out:
# {'target_1_day': Site            BK      LP      MS
#  2020-01-02    32.0   184.0     0.0
#  2020-01-03     0.0     1.0     0.0
#  2020-01-04     0.0     0.0     0.0
#  2020-01-05    50.0   696.0     0.0
#  2020-01-06  2368.0  2114.0   373.0
#  ...            ...     ...     ...
#  2023-12-18  3863.0   961.0  2993.0
#  2023-12-19  3544.0  1296.0  2689.0
#  2023-12-20    83.0   280.0  1640.0
#  2023-12-21    16.0     0.0   551.0
#  2023-12-22     NaN     NaN     NaN
#
#  [1451 rows x 3 columns],
#  'target_2_5_days': Site             BK       LP      MS
#  2020-01-02   604.50   702.75   93.25
#  2020-01-03  1715.50  2030.00  215.00
#  2020-01-04  2625.25  3259.00  345.75
#  2020-01-05  2856.25  3509.50  386.25
#  2020-01-06  2264.25  2981.00  293.00
#  ...             ...      ...     ...
#  2023-12-18      NaN      NaN     NaN
#  2023-12-19      NaN      NaN     NaN
#  2023-12-20      NaN      NaN     NaN
#  2023-12-21      NaN      NaN     NaN
#  2023-12-22      NaN      NaN     NaN
#
#  [1451 rows x 3 columns],
#  'target_6_10_days': Site            BK      LP     MS
#  2020-01-02  1811.4  2384.8  234.4
#  2020-01-03  1911.8  2380.8  227.4
#  2020-01-04  1704.2  1840.2  199.6
#  2020-01-05  2457.0  3598.0  262.4
#  2020-01-06  3333.2  4698.2  374.4
#  ...            ...     ...    ...
#  2023-12-18     NaN     NaN    NaN
#  2023-12-19     NaN     NaN    NaN
#  2023-12-20     NaN     NaN    NaN
#  2023-12-21     NaN     NaN    NaN
#  2023-12-22     NaN     NaN    NaN
#
#  [1451 rows x 3 columns]}

# %%
# --- 3. & 4. ROBUST MODELING & EVALUATION PER SITE ---
print("--- Steps 3 & 4: Robust Modeling & Evaluation Per Site ---")
print("Goal: Train and evaluate a model for each site and horizon using rolling cross-validation.")

# Best Practice: Use TimeSeriesSplit for robust evaluation.
tscv = TimeSeriesSplit(n_splits=5)
sites = pivot_demand.columns
models = {} # Store final production models
evaluation_results = []
all_test_sets = {} # To store test data for later analysis

# Custom cost function as defined previously
def asymmetric_loss(y_true, y_pred):
    errors = y_true - y_pred
    loss = np.where(errors < 0, errors**2 * 1.5, errors**2)
    return np.sqrt(np.mean(loss))

# Store the target dataframes in a dictionary for easy access in the loop.
target_dfs = {
    'target_1_day': targets_1_day,
    'target_2_5_days': targets_2_5_days,
    'target_6_10_days': targets_6_10_days,
}

for site in sites:
    print(f"\n--- Processing Site: {site} ---")
    models[site] = {}
    all_test_sets[site] = {}

    # Create site-specific lag and rolling features here. This prevents leakage.
    site_features = time_features.copy()
    for lag in [1, 2, 3, 7, 14, 21]:
        site_features[f'site_lag_{lag}'] = pivot_demand[site].shift(lag)

    site_features['site_rolling_mean_7'] = pivot_demand[site].shift(1).rolling(window=7).mean()
    site_features['site_rolling_mean_14'] = pivot_demand[site].shift(1).rolling(window=14).mean()

    # Loop through the target_dfs dictionary.
    for horizon_name, target_df in target_dfs.items():
        print(f"  Training and evaluating model for horizon: {horizon_name}")

        # Align features and target, and drop NaNs.
        # Select the target series for the current site and horizon from the correct DataFrame.
        y_series = target_df[site]
        temp_df = pd.concat([site_features, y_series.rename('target')], axis=1).dropna()
        X = temp_df.drop('target', axis=1)
        y = temp_df['target']

        fold_scores = []
        # Use the CV loop for evaluation, not for training the final model.
        # We save the last fold's test set for later visualization.
        last_fold_y_test = None
        last_fold_y_pred = None

        for i, (train_index, test_index) in enumerate(tscv.split(X)):
            X_train, X_test = X.iloc[train_index], X.iloc[test_index]
            y_train, y_test = y.iloc[train_index], y.iloc[test_index]

            model_eval = RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1, min_samples_leaf=5)
            model_eval.fit(X_train, y_train)
            y_pred = model_eval.predict(X_test)

            score = asymmetric_loss(y_test, y_pred)
            fold_scores.append(score)

            if i == tscv.n_splits - 1: # Save last fold for analysis
                last_fold_y_test = y_test
                last_fold_y_pred = y_pred

        avg_loss = np.mean(fold_scores)
        evaluation_results.append({'Site': site, 'Horizon': horizon_name, 'Avg_Asymmetric_Loss': avg_loss})
        all_test_sets[site][horizon_name] = {'y_test': last_fold_y_test, 'y_pred': last_fold_y_pred}
        print(f"    - Avg. Asymmetric Loss across {tscv.n_splits} folds: {avg_loss:.2f}")

        # Now, train the FINAL model for this site/horizon on ALL available data.
        # This model is what we'll use for future predictions.
        print(f"  Training final production model for {horizon_name}...")
        final_model = RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=-1, min_samples_leaf=5)
        final_model.fit(X, y)
        models[site][horizon_name] = {
            'model': final_model,
            'features': X.columns.tolist() # Store feature list
        }

results_df = pd.DataFrame(evaluation_results)
print("\n--- End of Steps 3 & 4 ---\n")
# Out:
# --- Steps 3 & 4: Robust Modeling & Evaluation Per Site ---
# Goal: Train and evaluate a model for each site and horizon using rolling cross-validation.
#
# --- Processing Site: BK ---
#   Training and evaluating model for horizon: target_1_day
#     - Avg. Asymmetric Loss across 5 folds: 1197.73
#   Training final production model for target_1_day...
#   Training and evaluating model for horizon: target_2_5_days
#     - Avg. Asymmetric Loss across 5 folds: 937.65
#   Training final production model for target_2_5_days...
#   Training and evaluating model for horizon: target_6_10_days
#     - Avg. Asymmetric Loss across 5 folds: 1006.32
#   Training final production model for target_6_10_days...
#
# --- Processing Site: LP ---
#   Training and evaluating model for horizon: target_1_day
#     - Avg. Asymmetric Loss across 5 folds: 1087.03
#   Training final production model for target_1_day...
#   Training and evaluating model for horizon: target_2_5_days
#     - Avg. Asymmetric Loss across 5 folds: 884.15
#   Training final production model for target_2_5_days...
#   Training and evaluating model for horizon: target_6_10_days
#     - Avg. Asymmetric Loss across 5 folds: 903.79
#   Training final production model for target_6_10_days...
#
# --- Processing Site: MS ---
#   Training and evaluating model for horizon: target_1_day
#     - Avg. Asymmetric Loss across 5 folds: 397.18
#   Training final production model for target_1_day...
#   Training and evaluating model for horizon: target_2_5_days
#     - Avg. Asymmetric Loss across 5 folds: 331.21
#   Training final production model for target_2_5_days...
#   Training and evaluating model for horizon: target_6_10_days
#     - Avg. Asymmetric Loss across 5 folds: 342.17
#   Training final production model for target_6_10_days...
#
# --- End of Steps 3 & 4 ---

# %%
# --- 5. MODEL EVALUATION (WITH SAFETY BUFFER) ---
print("\n--- Step 5: Model Evaluation ---")
results_df = pd.DataFrame(evaluation_results)
performance_pivot = results_df.pivot(index='Site', columns='Horizon', values='Average_MAE')
plt.figure(figsize=(12, 8))
sns.heatmap(performance_pivot, annot=True, fmt=".2f", cmap="YlGnBu_r", linewidths=.5)
plt.title('Forecasting Performance (Average MAE) by Site and Horizon', fontsize=16)
plt.show()

# Visualize predictions for one example
if not models or not evaluation_results:
    print("No models were trained, skipping visualization.")
else:
    site_to_plot = results_df['Site'].iloc[0]
    horizon_to_plot = 'target_1_day'

    site_features_plot = time_features.copy()
    for lag in [1, 2, 3, 7, 14]:
        site_features_plot[f'site_lag_{lag}'] = pivot_demand[site_to_plot].shift(lag)
    site_features_plot['site_rolling_mean_7'] = pivot_demand[site_to_plot].shift(1).rolling(window=7).mean()
    site_features_plot['site_rolling_mean_14'] = pivot_demand[site_to_plot].shift(1).rolling(window=14).mean()
    site_features_plot = site_features_plot.ffill().bfill().fillna(0)

    y_series_plot = target_dfs[horizon_to_plot][site_to_plot]
    temp_df_plot = pd.concat([site_features_plot, y_series_plot.rename('target')], axis=1)
    temp_df_plot.dropna(subset=['target'], inplace=True)
    X_plot = temp_df_plot[reg_features]
    y_plot = temp_df_plot['target']

    plot_split_index = int(len(X_plot) * 0.8)
    X_test_plot = X_plot.iloc[plot_split_index:]
    y_test_plot = y_plot.iloc[plot_split_index:]

    final_model_to_plot = models[site_to_plot][horizon_to_plot]['model']
    y_pred_raw = final_model_to_plot.predict(X_test_plot)

    # --- CHANGE 1: APPLY SAFETY BUFFER FOR PLOTTING ---
    # To address the business rule that preparing too few meals is worse than too many,
    # we add a buffer to the predictions. This biases the forecast upwards.
    # A 5% buffer is used here as an example; this value can be tuned.
    safety_buffer_factor = 1.1
    y_pred_plot = y_pred_raw * safety_buffer_factor
    # --- END OF CHANGE ---

    plt.figure(figsize=(15, 7))
    plt.plot(y_test_plot.index, y_test_plot, label='Actual Values', color='blue', alpha=0.7, zorder=2)
    plt.plot(y_test_plot.index, y_pred_plot, label=f'Predicted Values (with {int((safety_buffer_factor-1)*100)}% Buffer)', color='red', linestyle='--', zorder=3)
    # Optional: plot raw prediction to see the difference
    plt.plot(y_test_plot.index, y_pred_raw, label='Original Prediction', color='orange', linestyle=':', alpha=0.6, zorder=1)
    plt.title(f'Final Model Forecast vs. Actuals for {site_to_plot} ({horizon_to_plot})')
    plt.xlabel('Date')
    plt.ylabel('Net Meal Quantity')
    plt.legend()
    plt.grid(True)
    plt.show()

print("\n--- End of Step 5 ---")
# Out:
# --- Step 5: Model Evaluation ---
# --- End of Step 5 ---

# %%
# show worst predications

# %%
# --- 6. GENERATING FUTURE FORECASTS (WITH SAFETY BUFFER) ---
print("\n--- Step 6: Generating Future Forecasts ---")

last_date = pivot_demand.index.max()
future_dates = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=14, freq='D')

future_features_base = pd.DataFrame(index=future_dates)
future_features_base['day_of_year'] = future_features_base.index.dayofyear
future_features_base['weekday'] = future_features_base.index.weekday
future_features_base['is_weekend'] = (future_features_base.index.weekday >= 5).astype(int)
future_features_base['month'] = future_features_base.index.month
future_features_base['quarter'] = future_features_base.index.quarter
future_features_base['day_of_month'] = future_features_base.index.day
future_features_base['sin_doy'] = np.sin(2 * np.pi * future_features_base['day_of_year'] / 365.25)
future_features_base['cos_doy'] = np.cos(2 * np.pi * future_features_base['day_of_year'] / 365.25)
future_features_base['is_holiday'] = future_features_base.index.to_series().apply(lambda x: int(x in de_holidays))

future_predictions = {}
full_pivot_history = pd.concat([pivot_demand, pd.DataFrame(index=future_dates)])

for site in models:
    future_predictions[site] = {}
    temp_future_features = future_features_base.copy()
    full_series = pd.concat([pivot_demand[site], pd.Series(index=temp_future_features.index, dtype='float64')])

    # Recreate all features exactly as they were for training
    for lag in [1, 2, 3, 7, 14]:
        temp_future_features[f'lag_{lag}'] = full_pivot_history.shift(lag).mean(axis=1).loc[temp_future_features.index]
    temp_future_features['rolling_mean_7'] = temp_future_features['lag_1'].rolling(window=7, min_periods=1).mean()
    temp_future_features['rolling_mean_14'] = temp_future_features['lag_1'].rolling(window=14, min_periods=1).mean()
    for lag in [1, 2, 3, 7, 14]:
        temp_future_features[f'site_lag_{lag}'] = full_series.shift(lag).loc[temp_future_features.index]
    temp_future_features['site_rolling_mean_7'] = full_series.shift(1).rolling(window=7, min_periods=1).mean().loc[
        temp_future_features.index]
    temp_future_features['site_rolling_mean_14'] = full_series.shift(1).rolling(window=14, min_periods=1).mean().loc[
        temp_future_features.index]

    temp_future_features = temp_future_features.ffill().bfill().fillna(0)

    for horizon, model_info in models[site].items():
        model = model_info['model']
        X_future = temp_future_features[reg_features]
        raw_predictions = model.predict(X_future)

        # --- APPLY SAFETY BUFFER FOR FUTURE FORECASTS ---
        safety_buffer_factor = 1.1  # Use the same factor as in evaluation
        predictions = raw_predictions * safety_buffer_factor
        future_predictions[site][horizon] = predictions

# --- ROUND UP FORECASTS ---
forecast_day_1 = pd.DataFrame({
    site: {
        horizon: f"{int(np.ceil(preds[0]))} meals" for horizon, preds in site_preds.items()
    } for site, site_preds in future_predictions.items()
}).T

# --- VISUALIZATION OF FUTURE FORECASTS (FIX FOR USERWARNING) ---
# The original code mixed pandas and matplotlib plotting functions, causing a warning.
# This version uses a consistent approach to prevent it.
for site in future_predictions:
    # Create a new figure and axes for each plot to ensure they are clean
    fig, ax = plt.subplots(figsize=(15, 7))

    # Plot historical data using pandas on the created axes
    pivot_demand[site].tail(30).plot(label='Historical Demand', color='black', alpha=0.7, ax=ax)

    # Plot only the clearest, 1-day ahead forecast
    horizon_to_plot = 'target_1_day'
    if horizon_to_plot in future_predictions[site]:
        # Create a pandas Series for the forecast so we can use the pandas .plot() method,
        # which avoids the converter warning.
        forecast_series = pd.Series(future_predictions[site][horizon_to_plot], index=future_dates)
        forecast_series.plot(label=f'Forecast (with Buffer)', linestyle='--', marker='o', ax=ax)

    # Use the axes object to set plot properties
    ax.set_title(f'14-Day Demand Forecast for {site}', fontsize=16)
    ax.set_xlabel('Date')
    ax.set_ylabel('Predicted Meals')
    ax.legend()
    ax.grid(True, linestyle='--', alpha=0.6)
    plt.show()

print("\nSample Forecast for the next available day:")
print(forecast_day_1)
print("\n--- End of Step 6 ---")
# Out:
# --- Step 6: Generating Future Forecasts ---
# Sample Forecast for the next available day:
#    target_1_day target_2_5_days target_6_10_days
# BK    724 meals       800 meals         77 meals
# LP    270 meals       932 meals        385 meals
# MS     73 meals      2641 meals       1949 meals
#
# --- End of Step 6 ---

# %%
for site in future_predictions:
    plt.figure(figsize=(12, 5))
    for horizon in future_predictions[site]:
        plt.plot(future_dates, future_predictions[site][horizon], label=horizon)
    plt.title(f'Future Forecasts for {site}')
    plt.xlabel('Date')
    plt.ylabel('Predicted Meals')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
# --- 7. IN-DEPTH ANALYSIS AND VISUALIZATION (SITE-SPECIFIC) ---
print("\n--- Step 7: In-Depth Analysis and Visualization (Site-Specific) ---")
# This updated section provides deeper insights broken down by each kitchen site.

# 7.1. Model Performance Summary Table
print("\n--- 7.1. Model Performance Summary ---")
performance_pivot = results_df.pivot(index='Site', columns='Horizon', values='Avg_Asymmetric_Loss')
print("Average Asymmetric Loss by Site and Horizon:")
display(performance_pivot.style.background_gradient(cmap='Reds', axis=None).format("{:.2f}"))

# 7.2. Site-Specific Analysis Loop
for site in sites:
    print(f"\n{'='*25} ANALYSIS FOR SITE: {site} {'='*25}")

    # --- Feature Importance Visualization ---
    print(f"\n--- 7.2.1. Feature Importance for {site} ---")
    # Visualize feature importances for the 1-day horizon model for the current site
    sample_horizon = 'target_1_day'
    model_to_inspect = models[site][sample_horizon]['model']
    features_to_inspect = models[site][sample_horizon]['features']

    feature_importances_forecast = pd.DataFrame({
        'feature': features_to_inspect,
        'importance': model_to_inspect.feature_importances_
    }).sort_values('importance', ascending=False)

    plt.figure(figsize=(12, 8))
    sns.barplot(x='importance', y='feature', data=feature_importances_forecast.head(15), palette='mako')
    plt.title(f'Top 15 Feature Importances for Forecasting\n(Site: {site}, Horizon: {sample_horizon})')
    plt.xlabel('Importance')
    plt.ylabel('Feature')
    plt.tight_layout()
    plt.show()

    # --- Prediction vs. Actuals Plot ---
    print(f"\n--- 7.2.2. Prediction vs. Actuals Plot for {site} ---")
    print(f"Visualizing performance on the last cross-validation fold for the 1-day horizon.")
    test_data = all_test_sets[site][sample_horizon]
    y_test = test_data['y_test']
    y_pred = test_data['y_pred']

    plt.figure(figsize=(15, 7))
    plt.plot(y_test.index, y_test, label='Actual Values', color='dodgerblue', alpha=0.8, marker='o', markersize=5, linestyle='-')
    plt.plot(y_test.index, y_pred, label='Predicted Values', color='red', linestyle='--')
    plt.title(f'Forecast vs. Actuals for {site} (1-Day Horizon)')
    plt.xlabel('Date')
    plt.ylabel('Net Meal Quantity')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.show()

    # --- Error Analysis ---
    print(f"\n--- 7.2.3. Error Analysis for {site} ---")
    errors = y_test - y_pred

    # Plot 1: Error Distribution
    plt.figure(figsize=(10, 6))
    sns.histplot(errors, kde=True, bins=30)
    plt.axvline(x=0, color='red', linestyle='--', label='Zero Error (Perfect Prediction)')
    under_pred_pct = (errors > 0).mean() * 100
    over_pred_pct = (errors < 0).mean() * 100
    plt.title(f'Distribution of Prediction Errors for {site}\n(Under-predictions: {under_pred_pct:.1f}%, Over-predictions: {over_pred_pct:.1f}%)')
    plt.xlabel('Error (Actual - Predicted)')
    plt.ylabel('Frequency')
    plt.legend()
    plt.show()

    # Plot 2: Scatter Plot of Actual vs. Predicted
    plt.figure(figsize=(8, 8))
    max_val = max(y_test.max(), y_pred.max()) * 1.05
    plt.plot([0, max_val], [0, max_val], 'r--', label='Perfect Prediction')
    plt.scatter(y_test, y_pred, alpha=0.6, edgecolors='k')
    plt.title(f'Actual vs. Predicted Values for {site}')
    plt.xlabel('Actual Meal Quantity')
    plt.ylabel('Predicted Meal Quantity')
    plt.xlim(0, max_val)
    plt.ylim(0, max_val)
    plt.grid(True)
    plt.legend()
    plt.show()

print("\n--- End of Analysis ---")
# Out:
# --- Step 7: In-Depth Analysis and Visualization (Site-Specific) ---
#
# --- 7.1. Model Performance Summary ---
# Average Asymmetric Loss by Site and Horizon:
# <style type="text/css">
# #T_16281_row0_col0 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_16281_row0_col1 {
#   background-color: #d92523;
#   color: #f1f1f1;
# }
# #T_16281_row0_col2 {
#   background-color: #c2161b;
#   color: #f1f1f1;
# }
# #T_16281_row1_col0 {
#   background-color: #a50f15;
#   color: #f1f1f1;
# }
# #T_16281_row1_col1 {
#   background-color: #eb372a;
#   color: #f1f1f1;
# }
# #T_16281_row1_col2 {
#   background-color: #e43027;
#   color: #f1f1f1;
# }
# #T_16281_row2_col0 {
#   background-color: #fee8de;
#   color: #000000;
# }
# #T_16281_row2_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_16281_row2_col2 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# </style>
# <table id="T_16281">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Horizon</th>
#       <th id="T_16281_level0_col0" class="col_heading level0 col0" >target_1_day</th>
#       <th id="T_16281_level0_col1" class="col_heading level0 col1" >target_2_5_days</th>
#       <th id="T_16281_level0_col2" class="col_heading level0 col2" >target_6_10_days</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Site</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16281_level0_row0" class="row_heading level0 row0" >BK</th>
#       <td id="T_16281_row0_col0" class="data row0 col0" >1197.73</td>
#       <td id="T_16281_row0_col1" class="data row0 col1" >937.65</td>
#       <td id="T_16281_row0_col2" class="data row0 col2" >1006.32</td>
#     </tr>
#     <tr>
#       <th id="T_16281_level0_row1" class="row_heading level0 row1" >LP</th>
#       <td id="T_16281_row1_col0" class="data row1 col0" >1087.03</td>
#       <td id="T_16281_row1_col1" class="data row1 col1" >884.15</td>
#       <td id="T_16281_row1_col2" class="data row1 col2" >903.79</td>
#     </tr>
#     <tr>
#       <th id="T_16281_level0_row2" class="row_heading level0 row2" >MS</th>
#       <td id="T_16281_row2_col0" class="data row2 col0" >397.18</td>
#       <td id="T_16281_row2_col1" class="data row2 col1" >331.21</td>
#       <td id="T_16281_row2_col2" class="data row2 col2" >342.17</td>
#     </tr>
#   </tbody>
# </table>
# ========================= ANALYSIS FOR SITE: BK =========================
#
# --- 7.2.1. Feature Importance for BK ---
# /var/folders/_4/yzd4h3k95051tj7kpg425rk80000gn/T/ipykernel_97790/4068293730.py:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='importance', y='feature', data=feature_importances_forecast.head(15), palette='mako')
# --- 7.2.2. Prediction vs. Actuals Plot for BK ---
# Visualizing performance on the last cross-validation fold for the 1-day horizon.
# --- 7.2.3. Error Analysis for BK ---
# ========================= ANALYSIS FOR SITE: LP =========================
#
# --- 7.2.1. Feature Importance for LP ---
# /var/folders/_4/yzd4h3k95051tj7kpg425rk80000gn/T/ipykernel_97790/4068293730.py:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='importance', y='feature', data=feature_importances_forecast.head(15), palette='mako')
# --- 7.2.2. Prediction vs. Actuals Plot for LP ---
# Visualizing performance on the last cross-validation fold for the 1-day horizon.
# --- 7.2.3. Error Analysis for LP ---
# ========================= ANALYSIS FOR SITE: MS =========================
#
# --- 7.2.1. Feature Importance for MS ---
# /var/folders/_4/yzd4h3k95051tj7kpg425rk80000gn/T/ipykernel_97790/4068293730.py:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='importance', y='feature', data=feature_importances_forecast.head(15), palette='mako')
# --- 7.2.2. Prediction vs. Actuals Plot for MS ---
# Visualizing performance on the last cross-validation fold for the 1-day horizon.
# --- 7.2.3. Error Analysis for MS ---
# --- End of Analysis ---

# %%
# --- 6. DISPLAY FORECASTS ---
print("\n--- Step 6: Display Forecasts ---")
# This section provides a clean, user-friendly table of the upcoming forecasts.

# Combine all forecasts into a user-friendly DataFrame
forecast_df_list = []
for site in all_forecasts:
    temp_df = pd.DataFrame(index=future_dates)
    temp_df['Site'] = site
    temp_df['Forecast_1_Day'] = np.round(all_forecasts[site]['target_1_day']).astype(int)
    temp_df['Forecast_2_5_Days_Avg'] = np.round(all_forecasts[site]['target_2_5_days']).astype(int)
    temp_df['Forecast_6_10_Days_Avg'] = np.round(all_forecasts[site]['target_6_10_days']).astype(int)
    forecast_df_list.append(temp_df)

final_forecast_table = pd.concat(forecast_df_list).reset_index().rename(columns={'index': 'Date'})

print("Future Forecasts for All Sites (Next 14 Days):")
# Use styling for better readability in notebooks
styled_table = final_forecast_table.style.background_gradient(cmap='viridis', subset=['Forecast_1_Day', 'Forecast_2_5_Days_Avg', 'Forecast_6_10_Days_Avg']).format({'Date': '{:%Y-%m-%d}'})
display(styled_table)
print("\n--- End of Step 6 ---")
# Out:
# --- Step 6: Display Forecasts ---
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 10
#       8 temp_df = pd.DataFrame(index=future_dates)
#       9 temp_df['Site'] = site
# ---> 10 temp_df['Forecast_1_Day'] = np.round(all_forecasts[site]['target_1_day']).astype(int)
#      11 temp_df['Forecast_2_5_Days_Avg'] = np.round(all_forecasts[site]['target_2_5_days']).astype(int)
#      12 temp_df['Forecast_6_10_Days_Avg'] = np.round(all_forecasts[site]['target_6_10_days']).astype(int)
#
# TypeError: list indices must be integers or slices, not dict

# %%
column_names = df.columns.tolist()

print(column_names)
# Out:
# ['DateOfOrder', 'OrderId', 'TransactionId', 'DateOfService', 'OrderQty', 'MenuName', 'MenuPrice', 'MenuSubsidy', 'BookingNr', 'GroupName', 'CanceledQty', 'DateOfCancel', 'Site', 'SchoolID', 'net_qty', 'days_to_cancel', 'MenuNorm', 'MenuBase', 'MenuCode', 'day_of_year', 'weekday', 'is_weekend', 'sin_doy', 'cos_doy', 'cancel_timing', 'subsidy_pct', 'month', 'quarter', 'day_of_month', 'is_month_end', 'is_month_start', 'order_hour', 'morning', 'afternoon', 'evening', 'hist_cancel_rate', 'is_holiday', 'is_canceled']
